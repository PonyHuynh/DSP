# %% [markdown]
# #### Khoa Điện tử Viễn thông- Trường Đại học Khoa học tự nhiên<br>
# -------------------------------------------------------------------------
# # <center>Bài 2: HỆ THỐNG RỜI RẠC TRONG MIỀN THỜI GIAN </center><br>
# Nhóm: <br>
# Họ và tên: Huỳnh Thị Mai Phương
# MSSV:20200315
# #### Mục đích:
# > * Minh họa hoạt động của hệ thống rời rạc thời gian LTI <br>
# > * Minh họa các tính chất trong miền thời gian của hệ thống rời rạc thời gian LTI<br>

# %% [markdown]
# Thêm thư viện vào project

# %%
#Thêm thư viện
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np

# %% [markdown]
# Bài 1a: <br>
# > Xem hệ thống rời rạc thời gian có phương trình tín hiệu vào ra: $ y(n) = 1.5y(n−1)−0.85y(n−2) + x(n)$ <br>
# Điều kiện ban đầu của hệ thống $y(−2) = y(−1) = 0.$ <br>
# Đoạn code sau đây tính và vẽ 10 giá trị đầu tiên của y(n) ứng với tín hiệu vào $x = [1, 3, -2, 4, -6, 8, 7, 15, 12, 0]$

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
n = np.arange(10)
x = [1, 3, -2, 4, -6, 8, 7, 15, 12, 0] #Khai báo tín hiệu x
y = np.zeros(12) #Khởi tạo mảng y gồm 12 phần tử có giá trị 0
for i in range(2,12): #i chạy từ 2 đến 11
    y[i] = 1.5*y[i-1] - 0.85*y[i-2] + x[i-2] #Lưu ý đến x[i-2]
y = y[2:12] #Gán lại giá trị y bằng phần tử 2 đến 11
plt.subplot(2, 1, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(2, 1, 2)
plt.stem(n,y)
plt.title("Tín hiệu ra")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# Text(0, 0.5, 'Biên độ')

# %%
#Cách 2
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
n = np.arange(10)
x = [1, 3, -2, 4, -6, 8, 7, 15, 12, 0]
y = np.zeros(10)
for i in range(0,10): #range(10)
    y[i] = 1.5*y[i-1] - 0.85*y[i-2] + x[i]
plt.subplot(2, 1, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(2, 1, 2)
plt.stem(n,y)
plt.title("Tín hiệu ra")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 1b:<br>
#  > Thực hiện lại bài 1a sử dụng hàm $lfilter()$

# %%
n = np.arange(10)
x = [1, 3, -2, 4, -6, 8, 7, 15, 12, 0]
b = [1] #Các hệ số của x
a = [1, -1.5, 0.85] #Các hệ số của y, lưu ý đến dấu của các hệ số
'''
a, b là hệ số của phương trình vào ra:

a[0]*y[n] = b[0]*x[n] + b[1]*x[n-1] + ... + b[M]*x[n-M]
                      - a[1]*y[n-1] - ... - a[N]*y[n-N]
Hoặc viết dưới dạng hàm chuyển biến đổi z: b là các hệ số của tử số, a là các hệ số của mẫu số
                    -1              -M
        b[0] + b[1]z  + ... + b[M] z
Y(z) = -------------------------------- X(z)
                    -1              -N
        a[0] + a[1]z  + ... + a[N] z
'''
y = signal.lfilter(b, a, x)

plt.subplot(2, 1, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(2, 1, 2)
plt.stem(n,y)
print("tín hiệu ra", y)
plt.title("Tín hiệu ra")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# tín hiệu ra [ 1.          4.5         3.9         6.025      -0.2775      2.4625
#  10.929625   29.3013125  46.6617875  45.08656563]
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 2a:<br>
# > Cho hệ thống rời rạc thời gian có phương trình tín hiệu vào ra: <br>
# > $y(n) = 1.2x(n)−0.85x(n−1) + x(n−2)$ <br>
# Tính và vẽ tín hiệu ra y(n) với tín hiệu vào $x = [1.5, -4, 6, 2.5, -3, 0, 0, 0, 0, 0] $<br>
# (Sử dụng vòng lặp for)

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
n = np.arange(10)
x = [0,0,1.5, -4, 6, 2.5, -3, 0, 0, 0, 0, 0]
y = np.zeros(12)
for i in range(2,12): #range(10)
    y[i] = 1.2*x[i] - 0.85*x[i-1] + x[i-2]
y=y[2:12]
x=x[2:12]

plt.subplot(1, 2, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(1, 2, 2)
plt.stem(n,y)
plt.title("Tín hiệu ra")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 2b: <br>
# > Thực hiện lại bài 2a sử dụng hàm $lfilter$

# %%
n = np.arange(10)
x = [1.5, -4, 6, 2.5, -3, 0, 0, 0, 0, 0]
b = [1.2, -0.85, 1] #Các hệ số của x
a = [1] #Các hệ số của y, lưu ý đến dấu của các hệ số
'''
a, b là hệ số của phương trình vào ra:

a[0]*y[n] = b[0]*x[n] + b[1]*x[n-1] + ... + b[M]*x[n-M]
                      - a[1]*y[n-1] - ... - a[N]*y[n-N]
Hoặc viết dưới dạng hàm chuyển biến đổi z: b là các hệ số của tử số, a là các hệ số của mẫu số
                    -1              -M
        b[0] + b[1]z  + ... + b[M] z
Y(z) = -------------------------------- X(z)
                    -1              -N
        a[0] + a[1]z  + ... + a[N] z
'''
y = signal.lfilter(b, a, x)

plt.subplot(1, 2, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(1, 2, 2)
plt.stem(n,y)
plt.title("Tín hiệu ra")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 3a: <br>
# > Đoạn chương sau đây tính và vẽ đáp ứng xung của hệ thống ở bài 2

# %%
n = np.arange(10)
x = signal.unit_impulse(10)
a = [1, 0, 0]
b = [1.2, -0.85, 1]
h = signal.lfilter(b, a, x)
print(h)
plt.subplot(2, 1, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(2, 1, 2)
plt.stem(n,h)
plt.title("Đáp ứng xung")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# [ 1.2  -0.85  1.    0.    0.    0.    0.    0.    0.    0.  ]
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 3b: (SV tự đọc) <br>
# > Thực hiện lại với hàm $dimpulse()$

# %%
n = np.arange(10)
x = signal.unit_impulse(10)
a = [1, 0, 0]
b = [1.2, -0.85, 1]
system = (b, a, 1.0) # dt=1.0 là thời gian lấy mẫu của hệ thống (tính bằng giây)
t, y = signal.dimpulse(system, n =10) #t là thời gian, y là mảng 2 chiều đáp ứng xung
h = y[0].flatten() #Đáp ứng xung
print(h)# In ra các giá trị của h
plt.subplot(2, 1, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(2, 1, 2)
plt.stem(n,h)
plt.title("Đáp ứng xung")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# [ 1.2  -0.85  1.    0.    0.    0.    0.    0.    0.    0.  ]
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 4a: <br>
# > Cho hệ thống có phương trình hiệu số $y(n) = x(n)+2x(n-1)-x(n-2)+x(n-3)$ và tín hiệu vào $ x = [1.0,1,2,1,2,2,1,1]$ <br>
# > a. Tìm đáp ứng xung h của hệ thống <br>
# > b. Tính và vẽ tín hiệu ngõ ra của hệ thống

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
n = np.arange(10)
x = [1.0,1,2,1,2,2,1,1,0,0]
y = np.zeros(10)
for i in range(0,10): #range(10)
    y[i] = 1*x[i] + 2*x[i-1] - x[i-2] + x[i-3]

plt.subplot(2, 2, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")

plt.subplot(2, 2, 2)
print("tín hiệu ngõ ra y =", y)
plt.stem(n,y)
plt.title("Tín hiệu ra")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
x = signal.unit_impulse(10)
a = [1]
b = [1, 2, -1, 1]
h = signal.lfilter(b, a, x)
print("đáp ứng xung h =", h)

plt.subplot(2, 2, 3)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")

plt.subplot(2, 2, 4)
plt.stem(n,h)
plt.title("Đáp ứng xung")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# tín hiệu ngõ ra y = [2. 3. 3. 5. 3. 7. 4. 3. 3. 0.]
# đáp ứng xung h = [ 1.  2. -1.  1.  0.  0.  0.  0.  0.  0.]
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 4b: <br>
# > Cho lọc FIR có đáp ứng xung là $h(n) = [0.5, -1.5, 0.85]$ <br>
# Viết phương trình vào ra của hệ thống

# %%
#phương trình vào: y(n) = 0.5x(n) - 1.5x(n-1) + 0.85x(n-2)

# %% [markdown]
# Bài 5a: <br>
# > Cho: <br>
# $x = [1.5, -4, 6, 2.5, -3, 0, 0, 0, 0, 0] $(Tín hiệu ở câu 2) <br>
# $h = [ 1.2,  -0.85, 1, 0, 0]$  (Đáp ứng xung ở câu 3)<br>
# Đoạn chương trình sau thực hiện nhân chập tín hiệu h với tín hiệu x được tín hiệu y. Vẽ tín hiệu x và y vừa tìm được sử dụng $subplot()$

# %%
n = np.arange(10)
x = [1.5, -4, 6, 2.5, -3, 0, 0, 0, 0, 0]
h = [ 1.2, -0.85, 1, 0, 0] 
y = np.zeros(10)
for i in range(10):
    for j in range(3):
        if i>= j:
            y[i] = y[i] + h[j]*x[i-j]
print(y) # Xem kết quả
plt.subplot(2, 1, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(2, 1, 2)
plt.stem(n,y)
plt.title("Tín hiệu ra")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# [ 1.8   -6.075 12.1   -6.1    0.275  5.05  -3.     0.     0.     0.   ]
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 5b: <br>
# > Thực hiện lại bài 4a với hàm $convolve()$ từ thư viện $signal$

# %%
n = np.arange(10)
x = [1.5, -4, 6, 2.5, -3, 0, 0, 0, 0, 0]
h = [ 1.2, -0.85, 1, 0, 0, 0, 0, 0, 0, 0] 
y = signal.convolve(x, h, mode='full')
y = y[:10]
print(y) # Xem kết quả
plt.subplot(2, 1, 1)
plt.stem(n,x)
plt.title("Tín hiệu vào")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.subplot(2, 1, 2)
plt.stem(n,y)
plt.title("Tín hiệu ra")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
# Out:
# [ 1.8   -6.075 12.1   -6.1    0.275  5.05  -3.     0.     0.     0.   ]
# Text(0, 0.5, 'Biên độ')

# %% [markdown]
# Bài 6a: <br>
# > Bộ lọc thấp qua có phương trình tín hiệu vào ra: $$y(n)=\frac{1}{M}\sum_{k=0}^{M-1}x(n-k)$$ <br>
# > a. Viết phương trình vào ra của bộ lọc khi M = 2 <br>
# > b. Tìm đáp ứng xung h của bộ lọc <br>
# > c. Tìm các hệ số a và b của hệ thống

# %%
#a) y(n) = 1/2*x(n) + 1/2*x(n-1)
#b) h(n) = 1/2*δ(𝑛) + 1/2*δ(𝑛-1)
#c) a = 1
#   b = 1/2, 1/2

# %% [markdown]
# Bài 6b: <br>
# > Tạo và vẽ tín hiệu s tổng hợp từ 2 tín hiệu sin s1 và s2 (fs = 10Hz, t = 50)như sau:
# >> s1: f1 = 0.05Hz, a1 = 1,  pha ban đầu = 0 <br>
# >> s2: f2 = 1Hz, a2 = 0.5,  pha ban đầu = 0 <br>
#
# > Hướng dẫn: tạo s1 bằng câu lệnh: $s1 =  a1*np.sin(2*np.pi*f*n)$

# %%
t = 50 #Thời gian của tín hiệu
fs = 10
n = np.linspace(0, t, fs*t, endpoint=False)
f1 = 0.05
f2 = 1
a1 = 1
a2 = 0.5
s1 = a1*np.sin(2*np.pi*f1*n)
s2 = a2*np.sin(2*np.pi*f2*n)
s = s1+s2 # Cộng 2 tín hiệu 
plt.plot(n, s)
plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
plt.xlim(0, 50)
# Out:
# (0.0, 50.0)

# %% [markdown]
# Bài 6c: <br>
# > Thực hiện lọc tín hiệu s với bộ lọc ở câu 6a (M= 10), sử dụng hàm $lfilter()$. Vẽ tín hiệu s1, s2, s và tín hiệu ra y sử dụng subplot() và plot()<br>
# Nhận xét tính hiệu y và s1

# %%
n = np.linspace(0,50,500, endpoint = False)
s1 = np.sin(2*np.pi*0.05*n)
s2 = 0.5*np.sin(2*np.pi*1*n)
s = s1 + s2
# lọc
a = [1]
M = 10
b = 1/M*np.ones(M)
y = signal.lfilter(b, a, s)
plt.subplot(4, 1, 1)
plt.plot(n, s1)
plt.title("Tin hieu s1")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 2)
plt.plot(n, s2)
plt.title("Tin hieu s2")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 3)
plt.plot(n, s)
plt.title("Tin hieu  vao s")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 4)
plt.plot(n, y)
plt.title("Tin hieu ra y")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)
# Out:
# (0.0, 50.0)

# %% [markdown]
# Bài 6d: <br>
# Thực hiện lọc tín hiệu s với bộ lọc ở câu 6a, sử dụng nhân chập từ hàm convolve(). Vẽ tín hiệu s1, s2, s và tín hiệu ra y sử dụng subplot() và plot()

# %%
n = np.linspace(0,50,500, endpoint = False)
s1 = np.sin(2*np.pi*0.05*n)
s2 = 0.5*np.sin(2*np.pi*1*n)
s = s1 + s2
# lọc
a = [1]
M = 10
b = 1/M*np.ones(M)
y = signal.convolve(b, s)
y = y[:500] #  lấy mẫu 500 đầu tiên
plt.subplot(4, 1, 1)
plt.plot(n, s1)
plt.title("Tin hieu s1")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 2)
plt.plot(n, s2)
plt.title("Tin hieu s2")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 3)
plt.plot(n, s)
plt.title("Tin hieu  vao s")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 4)
plt.plot(n, y)
plt.title("Tin hieu ra y")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)
# Out:
# (0.0, 50.0)

# %% [markdown]
# Bài 6e: <br>
# Thay đổi M từ 10 thành 15, 20, 35 và nhận xét tín hiệu ngõ ra

# %%
n = np.linspace(0,50,500, endpoint = False)
s1 = np.sin(2*np.pi*0.05*n)
s2 = 0.5*np.sin(2*np.pi*1*n)
s = s1 + s2
# lọc
a = [1]
M = 30
b = 1/M*np.ones(M)
y = signal.convolve(b, s)
y = y[:500] #  lấy mẫu 500 đầu tiên
plt.subplot(4, 1, 1)
plt.plot(n, s1)
plt.title("Tin hieu s1")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 2)
plt.plot(n, s2)
plt.title("Tin hieu s2")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 3)
plt.plot(n, s)
plt.title("Tin hieu  vao s")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 4)
plt.plot(n, y)
plt.title("Tin hieu ra y")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

#Tín hiệu ra không hoàn toàn lọc hết do bậc lọc ảnh hưởng đến tần số cắt của mạch lọc vì thế ứng với từng M mạch lọc có 1 tần số cắt khác
# Out:
# (0.0, 50.0)

# %% [markdown]
# Bài 6f: <br>
# Cho M = 15, cho s2 = 0, thay đổi f1 = 0.2Hz. Vẽ tín hiệu ngõ ra. Nhận xét?

# %%
n = np.linspace(0,50,500, endpoint = False)
s1 = np.sin(2*np.pi*0.2*n)
s2 = 0*np.sin(2*np.pi*1*n)
s = s1 + s2
# lọc
a = [1]
M = 15
b = 1/M*np.ones(M)
y = signal.convolve(b, s)
y = y[:500] #  lấy mẫu 500 đầu tiên
plt.subplot(4, 1, 1)
plt.plot(n, s1)
plt.title("Tin hieu s1")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 2)
plt.plot(n, s2)
plt.title("Tin hieu s2")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)
plt.ylim(-1,1)

plt.subplot(4, 1, 3)
plt.plot(n, s)
plt.title("Tin hieu  vao s")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)

plt.subplot(4, 1, 4)
plt.plot(n, y)
plt.title("Tin hieu ra y")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.xlim(0, 50)
plt.ylim(-1,1)
#nhận xét :Sau khi quan sát tín hiệu s1,s2,tín hiệu vào s và tín hiệu ra y thì ta thấy tín hiệu thay đổi không đáng kể
# Out:
# (-1.0, 1.0)

# %% [markdown]
# Bài 6g: <br>
# Cho M = 15, cho s2 = 0, thay đổi f1 = 0.5Hz. Vẽ tín hiệu ngõ ra. Nhận xét?

# %%
n = np.linspace(0,50,500, endpoint = False)
s1 = np.sin(2*np.pi*0.5*n)
s2 = 0*np.sin(2*np.pi*1*n)
s = s1 + s2
# lọc
a = [1]
M = 15
b = 1/M*np.ones(M)
y = signal.convolve(b, s)
y = y[:500] 
plt.subplot(4, 1, 1)
plt.plot(n, s1)
plt.title("Tin hieu s1")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.ylim(-1,1)
plt.xlim(0, 50)

plt.subplot(4, 1, 2)
plt.plot(n, s2)
plt.title("Tin hieu s2")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.ylim(-1,1)
plt.xlim(0, 50)

plt.subplot(4, 1, 3)
plt.plot(n, s)
plt.title("Tin hieu  vao s")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.ylim(-1,1)
plt.xlim(0, 50)

plt.subplot(4, 1, 4)
plt.plot(n, y)
plt.title("Tin hieu ra y")
plt.xlabel("Chi so n")
plt.ylabel("Bien do")
plt.ylim(-1,1)
plt.xlim(0, 50)
# Nhận xét Sau khi qua sát tín hiệu s1,s2, tín hiệu vào s và tín hiệu ra y thì ta thấy được tín hiệu đã bị giảm biên độ và nằm ngoài tần số cắt
# Out:
# (0.0, 50.0)

# %% [markdown]
# Bài 7: <br>
# > Cho tín hiệu được tạo bằng Python như sau:<br>
# n = np.arange(300)/256 <br>
# x = np.cos(2\*np.pi\*10\*n) + np.cos(2\*np.pi\*100\*n)<br>
# > Cho 2 hệ thống, điều kiện ban đầu $ y(−2) = y(−1) = 0$:<br>
# >> H1: $ y(n) = 0.5x(n) + 0.27x(n−1) + 0.77x(n−2) $<br>
# >> H2: $y(n) = 0.45x(n)+0.5x(n−1)+0.45x(n−2)+0.53y(n−1)−0.46y(n−2)$ <br>
#
# > a. Cho biết tần số lấy mẫu fs của tín hiệu x <br>
# > b. Tìm và vẽ tín hiệu ngõ ra của 2 hệ thống khi tín hiệu vào là x <br>
# > c. Nhận xét

# %%
#fs= 256
#𝑦(𝑛)=0.5𝑥(𝑛)+0.27𝑥(𝑛−1)+0.77𝑥(𝑛−2) 



n = np.arange(300)/256
x = np.cos(2*np.pi*10*n) + np.cos(2*np.pi*100*n)

#H1
a1 = [1]
b1 = [0.5,0.27,0.77]

y1 = signal.lfilter(b1, a1, x)

plt.subplot(2, 1, 1)
plt.plot(n,y1)
plt.title("Tín hiệu ra H1")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.xlim(0, 1.2)


#H2
a2 = [1,-0.53,0.46]
b2 = [0.45,0.5,0.45]

y2 = signal.lfilter(b2, a2, x)

plt.subplot(2, 1, 2)
plt.plot(n,y2)
plt.title("Tín hiệu ra H2")
plt.xlabel("Chỉ số n")
plt.ylabel("Biên độ")
plt.xlim(0, 1.2)


# Nhận xét: Sau khi qua sát thì ta thấy trong trường hợp này hệ thống H1 lọc kém hơn H2
# Out:
# (0.0, 1.2)
