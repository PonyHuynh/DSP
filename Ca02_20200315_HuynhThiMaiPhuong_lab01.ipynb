# %% [markdown]
# #### Khoa Điện tử Viễn thông- Trường Đại học Khoa học tự nhiên<br>
# -------------------------------------------------------------------------
# # <center>Bài 1: TÍN HIỆU  TRONG MIỀN THỜI GIAN </center><br>
# Nhóm: <br>
# Họ và tên: Huỳnh Thị Mai Phương
#
# MSSV:20200315
# ## Mục đích:
# -Làm quen với xử lý tín hiệu với Python <br>
# -Tạo được các tín hiệu cơ bản<br>
# -Hiểu rõ các định lý lấy mẫu tín hiệu.

# %% [markdown]
# Thư viện hỗ trợ cho xử lý tín hiệu số trong Python: <br>
# -numpy: Giúp xử lý số học hoặc mảng <br>
# -matplotlib: Hỗ trợ vẽ tín hiệu<br>
# -scipy: Thư viện hỗ trợ xử lý tín hiệu số<br>
# Để sử dụng các thư viện này ta phải import trước khi sử dụng các hàm tương ứng

# %%
#import thư viện cho toàn bài lab
#Chạy đoạn lệnh này khi mở file để thêm thư viện cho toàn bộ project
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np

# %% [markdown]
# Xung lực đơn vị $\delta(n) = \begin{cases} 1, & n = 0 \\ 0, & n \neq 0 \end{cases}$

# %% [markdown]
# Bài 1a: <br>
# Một xung lực đơn vị d[n] có chiều dài N được tạo bằng câu lệnh: dn = signal.unit_impulse(N) <br>
# Đoạn chương trình sau tạo ra một xung lực đơn vị có số mẫu là 8

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
#Đây là 1 comment
dn = signal.unit_impulse(8) #Hàm unit_impulse được lấy từ thư viện signal
plt.stem(dn)
plt.title("Xung lực đơn vị")
plt.xlabel("Samples (Mẫu)")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 1b: <br>
# Đoạn chương trình sau thực hiện vẽ xung lực đơn vị có chiều dài là 8 và delay 2 đơn vị, $\delta(n-2)$

# %%
dn2 = signal.unit_impulse(8,2)
plt.stem(dn2)
plt.title("Xung lực đơn vị delay 2 mẫu")
plt.xlabel("Samples (Mẫu)")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 1c: <br>
# Viết chương trình tạo ra xung lực đơn vị có chiều dài là 20 và delay 5

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
dn2 = signal.unit_impulse(20,5)
plt.stem(dn2)
plt.title("Xung lực đơn vị delay 5 mẫu")
plt.xlabel("Samples (Mẫu)")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bậc đơn vị u(n) có công thức: <br>
# $u(n) = \begin{cases} 1, & n \ge 0 \\ 0, & n < 0 \end{cases}$

# %% [markdown]
# Bài 1d: Tín hiệu x(n) = u(n) - u(n-5) được thực hiện bởi chương trình sau

# %%
n = np.arange(5) #Tạo 1 mảng 5 phần tử n =[0, 1, 2, 3, 4]
x = np.ones(5) #Tạo 1 mảng 5 phần tử có giá trị 1, n = [1, 1, 1, 1, 1]
plt.stem(n,x)
plt.title("Bậc đơn vị")
plt.xlabel("Samples (Mẫu)")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 1e: Ví dụ về bậc đơn vị u(n) 10 mẫu

# %%
x = np.concatenate([np.zeros(5), np.ones(5)] )
n = np.arange(-5,5)
plt.stem(n, x)
plt.title("Bậc đơn vị")
plt.xlabel("Samples (Mẫu)")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 1f: Viết chương trình tạo ra bậc đơn vị có chiều dài là 20, delay 5 mẫu u(n-5)

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
x = np.concatenate([np.zeros(5), np.ones(15)] )
n = np.arange(0,20)
plt.stem(n, x)
plt.title("Bậc đơn vị")
plt.xlabel("Samples (Mẫu)")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 2a: Tạo sóng vuông từ signal.square()

# %%
from scipy import signal
import matplotlib.pyplot as plt
t = np.linspace(0, 1, 500, endpoint=False) #Tạo 1 dải tuyến tính từ 0 -> 1, số mẫu là 500, không lấy mẫu cuối cùng
s = signal.square(2 * np.pi * 5 * t, duty = 0.5) #Tạo sóng vuông tần số 5Hz, với tần số lấy mẫu là 500Hz
plt.plot(t, s)
plt.ylim(-2, 2) #Giới hạn trục y từ -2 đến 2
# Out:
# (-2.0, 2.0)

# %% [markdown]
# Bài 2b: Viết chương trình tạo sóng vuông tần số 10Hz, tần số lấy mẫu là 3KHz, duty cycle 75%

# %%
from scipy import signal
import matplotlib.pyplot as plt
t = np.linspace(0, 1, 3000, endpoint = False)
s = signal.square(2 * np.pi * 10 * t, duty = 0.75) #Tạo sóng vuông tần số 10Hz, với tần số lấy mẫu là 3000Hz
plt.plot(t, s)
plt.ylim(-2, 2) #Giới hạn trục y từ -2 đến 2
# Out:
# (-2.0, 2.0)

# %% [markdown]
# Bài 3a: Chương trình sau tạo ra một sóng sin tần số 2Hz, biên độ là 2V, pha ban đầu bằng 0, số mẫu N = 100

# %%
fs = 100 # Tốc độ lấy mẫu (Hz)
f = 2 # Tần số của tín hiệu
N = 100 # Số mẫu
n = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs
y = 2*np.sin(2*np.pi*f * n) #Tính biên độ của sóng sin

plt.stem(n,y, 'r' )
plt.title("Tín hiệu hình sin")
plt.xlabel("Time[Samples (Mẫu)]")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16464\1471293522.py:7: MatplotlibDeprecationWarning: Passing the linefmt parameter positionally is deprecated since Matplotlib 3.5; the parameter will become keyword-only two minor releases later.
#   plt.stem(n,y, 'r' )
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 3b: Viết chương trình tạo ra sóng sin biên độ 3V, tần số 1Hz, pha ban đầu 90 độ

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
fs = 100 # Tốc độ lấy mẫu (Hz)
f = 1 # Tần số của tín hiệu
N = 100 # Số mẫu
n = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs
y = 3*np.sin(2*np.pi*f * n +np.pi/2) #Tính biên độ của sóng sin

plt.stem(n,y, 'r' )
plt.title("Tín hiệu hình sin")
plt.xlabel("Time[Samples (Mẫu)]")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16464\3066527305.py:10: MatplotlibDeprecationWarning: Passing the linefmt parameter positionally is deprecated since Matplotlib 3.5; the parameter will become keyword-only two minor releases later.
#   plt.stem(n,y, 'r' )
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 3c: Thay thế câu lệnh vẽ bằng stem sang plot và step. Cho biết kết quả thu được

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
fs = 100 # Tốc độ lấy mẫu (Hz)
f = 1 # Tần số của tín hiệu
N = 100 # Số mẫu
n = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs
y = 3*np.sin(2*np.pi*f * n +np.pi/2) #Tính biên độ của sóng sin

plt.subplot(2,1,1)
plt.plot(n,y, 'r' )

plt.title("\nTín hiệu hình sin\n")
plt.xlabel("\nTime[Samples (Mẫu)]\n")
plt.ylabel("Amplitude (Biên độ)")

plt.subplot(2,1,2)
plt.step(n,y, 'r' )

plt.xlabel("\nTime[Samples (Mẫu)]\n")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 3d: Cho đoạn chương trình sau. Cho biết tần số, biên độ, pha ban đầu, và tần số lấy mẫu của tín hiệu y?

# %%
t = np.linspace(0, 1, 20, endpoint=False)
y = np.sin(3*np.pi*t+np.pi/6)

plt.stem(t, y, 'r' )
plt.title("Tín hiệu hình sin")
plt.xlabel("Time[Samples (Mẫu)]")
plt.ylabel("Amplitude (Biên độ)")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16464\1349109172.py:4: MatplotlibDeprecationWarning: Passing the linefmt parameter positionally is deprecated since Matplotlib 3.5; the parameter will become keyword-only two minor releases later.
#   plt.stem(t, y, 'r' )
# Text(0, 0.5, 'Amplitude (Biên độ)')

# %% [markdown]
# Bài 4a: Đoạn chương trính sau tạo tín hiệu tổng hợp từ 2 tín hiệu sin với tần số lần lượt là f1 = 10Hz và f2 = 1Hz

# %%
t = 4 #Thời gian của tín hiệu
fs = 100
n = np.linspace(0, t, fs*t, endpoint=False)
f1 = 10
f2 = 1
a1 = 3
a2 = 3
s1 = a1*np.sin(2*np.pi*f1*n)
s2 = a2*np.sin(2*np.pi*f2*n)
s = s1+s2 # Cộng 2 tín hiệu 
plt.plot(n, s)
plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
plt.xlim(0, 2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# Bài 4b: Thay đổi biên độ tín hiệu s1 ở câu 4a sang 0.5. Vẽ lại tín hiệu và nhận xét

# %%
t = 4 #Thời gian của tín hiệu
fs = 100
n = np.linspace(0, t, fs*t, endpoint=False)
f1 = 10
f2 = 1
a1 = 0.5
a2 = 3
s1 = a1*np.sin(2*np.pi*f1*n)
s2 = a2*np.sin(2*np.pi*f2*n)
s = s1+s2 # Cộng 2 tín hiệu 
plt.plot(n, s)
plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
#plt.xlim(0, 2)
# Out:
# Text(0, 0.5, 'Biên độ (V)')

# %% [markdown]
# Bài 4c:<br> Thay đổi biên độ tín hiệu s2 ở câu 4a sang 0.5, biên độ s1 = 3. Vẽ lại tín hiệu và nhận xét

# %%
t = 4 #Thời gian của tín hiệu
fs = 100
n = np.linspace(0, t, fs*t, endpoint=False)
f1 = 10
f2 = 1
a1 = 3
a2 = 0.5
s1 = a1*np.sin(2*np.pi*f1*n)
s2 = a2*np.sin(2*np.pi*f2*n)
s = s1+s2 # Cộng 2 tín hiệu 
plt.plot(n, s)
plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
plt.xlim(0, 2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# Bài 4d: Thực hiện tạo và vẽ tín hiệu tổng hợp sA = s1 + s2 từ 2 tín hiệu hình sin s1 và s2 với các thông số như sau: <br>
# s1: a1 = 5, f1 = 1KHz <br>
# s2: a2 = 1, f2 = 50Hz <br>
# Số mẫu: n = 1000 <br>
# Tần số lấy mẫu: fs = 8000 <br>

# %%
fs = 8000
N = 1000 # Số mẫu
n = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs
f1 = 1000
f2 = 50
a1 = 5
a2 = 1
s1 = a1*np.sin(2*np.pi*f1*n)
s2 = a2*np.sin(2*np.pi*f2*n)
sA = s1+s2 # Cộng 2 tín hiệu 
plt.plot(n, sA)
plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
plt.xlim(0, 0.02)
# Out:
# (0.0, 0.02)

# %% [markdown]
# Bài 4e:Thực hiện vẽ tín hiệu sB = s1*s2 với s1, s2 là các tín hiệu hình sin các thông số sau:<br>
# s1: a1 = 5, f1 = 1KHz <br>
# s2: a2 = 1, f2 = 50Hz <br>
# Số mẫu: n = 1000 <br>
# Tần số lấy mẫu: fs = 8000

# %%
fs = 8000
N = 1000 # Số mẫu
n = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs
f1 = 1000
f2 = 50
a1 = 5
a2 = 1
s1 = a1*np.sin(2*np.pi*f1*n)
s2 = a2*np.sin(2*np.pi*f2*n)
sB = s1*s2 # nhân 2 tín hiệu 
plt.plot(n, sB)
plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
plt.xlim(0, 0.02)
# Out:
# (0.0, 0.02)

# %% [markdown]
# Bài 4f: Vẽ lại tín hiệu s1, s2, sA và sB trên cùng hình vẽ sử dụng plt.subplot()

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
fs = 8000
N = 1000 # Số mẫu
n = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs
f1 = 1000
f2 = 50
a1 = 5
a2 = 1
s1 = a1*np.sin(2*np.pi*f1*n)
s2 = a2*np.sin(2*np.pi*f2*n)
sA = s1+s2 # Cộng 2 tín hiệu 
sB = s1*s2 

plt.subplot(2,2,1 )
plt.plot(n, s1)
plt.xlim(0, 0.02)

plt.subplot(2,2,2 )
plt.plot(n, s2)
plt.xlim(0, 0.02)

plt.subplot(2,2,3 )
plt.plot(n, sA)
plt.xlim(0, 0.02)

plt.subplot(2,2,4 )
plt.plot(n, sB)
plt.xlim(0, 0.02)

plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
#plt.xlim(0, 2)
# Out:
# Text(0, 0.5, 'Biên độ (V)')

# %% [markdown]
# Bài 5a:<br>
# Vẽ tín hiệu $s(t) = cos(2\pi t) + cos(8\pi t) + cos(12\pi t)$ và tín hiệu $ sa(t)= 3*cos(2\pi t) $ trên cùng 1 hình với tần số fs = 5 Hz, số mẫu N = 100. So sánh tần số của s và sa?

# %%
fs = 5
N = 100 # Số mẫu
t = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs

s = np.cos(2*np.pi*t) + np.cos(8*np.pi*t) + np.cos(12*np.pi*t)
sa = 1*np.sin(2*np.pi*t)

plt.plot(t, s, t, sa)

plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
plt.xlim(0, 20)
# Out:
# (0.0, 20.0)

# %% [markdown]
# Bài 5b: <br>
# Thay đổi fs từ 5Hz lần lượt sang 10Hz và 50Hz. Vẽ lại tín hiệu s và sa. Nhận xét?

# %%
fs = 10
N = 100 # Số mẫu
t = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs

s = np.cos(2*np.pi*t) + np.cos(8*np.pi*t) + np.cos(12*np.pi*t)
sa = 1*np.sin(2*np.pi*t)

plt.subplot(2,1,1)
plt.plot(t, s, t, sa)
plt.xlim(0, 4)

fs = 50
N = 100 # Số mẫu
t1 = np.arange(N)/fs #Tạo ra 100 mẫu với chu kỳ lấy mẫu là Ts = 1/fs

s1 = np.cos(2*np.pi*t1) + np.cos(8*np.pi*t1) + np.cos(12*np.pi*t1)
sa1 = 1*np.sin(2*np.pi*t1)

plt.subplot(2,1,2)
plt.plot(t1, s1, t1, sa1)
plt.xlim(0, 2)

plt.xlabel('Thời gian (s)')
plt.ylabel('Biên độ (V)')
# Out:
# Text(0, 0.5, 'Biên độ (V)')

# %% [markdown]
# Bài 6a: <br>
# Đoạn chương trình sau tạo và phát âm thanh sin thuần tần số 440Hz với fs = 44100Hz

# %%
import IPython.display as ipd #Thêm thư viện để display Audio
from scipy.io import wavfile #Để tạo file wav
fs = 44100 # tần số lấy mẫu
t = 1.5    # thời gian của âm thanh
f = 440 # Tần số của tín hiệu (note A4)
n = np.linspace(0, t, int(t*fs), endpoint=False) # tạo biến thời gian rời rạc
x = np.sin(2*np.pi*f*n)                # tạo sóng sin 440 Hz
ipd.Audio(x, rate=fs)
#Tạo file wav
#Tạo âm thanh PCM 16 bit
#x2 = np.iinfo(np.int16).max*x #Nhân biên độ với giá trị lớn nhất của số 16bit
#x_wav = np.array(x, dtype='int16') #Định dạng lại âm thanh 16 bit
#wavfile.write("sinAudio.wav", fs,x_wav)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Bài 6b: <br>
# Thay đổi tần số của tín hiệu bài 4a sang 392Hz (Note G4) và 523.25Hz (Note C5). Nhận xét

# %%
import IPython.display as ipd #Thêm thư viện để play Audio
fs = 44100 # tần số lấy mẫu
t = 1.5    # thời gian của âm thanh
f = 523.25 # Tần số của tín hiệu
n = np.linspace(0, t, int(t*fs), endpoint=False) # tạo biến thời gian rời rạc
x = np.sin(2*np.pi*f*n)                # tạo sóng sin 440 Hz
ipd.Audio(x, rate=fs)       #Phát Audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd #Thêm thư viện để play Audio
fs = 44100 # tần số lấy mẫu
t = 1.5    # thời gian của âm thanh
f = 392 # Tần số của tín hiệu
n = np.linspace(0, t, int(t*fs), endpoint=False) # tạo biến thời gian rời rạc
x = np.sin(2*np.pi*f*n)                # tạo sóng sin 440 Hz
ipd.Audio(x, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
